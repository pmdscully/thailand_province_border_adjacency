# %%
import pandas as pd

#df = pd.read_csv("phannisa_province_data_latlon.csv", encoding="iso8859_11")
df = pd.read_csv("phannisa_province_data_latlon_v02_utf8.csv")
df
# Out:
#     FID  ISO_province        PROV_NAMT                 PROV_NAME abbr_th  \
# 0     0            10    กรุงเทพมหานคร                   BANGKOK      กท
# 1     1            11      สมุทรปราการ              SAMUT PRAKAN      สป
# 2     2            12          นนทบุรี                NONTHABURI      นบ
# 3     3            13         ปทุมธานี              PATHUM THANI      ปท
# 4     4            14  พระนครศรีอยุธยา  PHRA NAKHON SI AYUTTHAYA      อย
# 5     5            15          อ่างทอง                 ANG THONG      อท
# 6     6            16           ลพบุรี                  LOP BURI      ลบ
# 7     7            17        สิงห์บุรี                 SING BURI      สห
# 8     8            18           ชัยนาท                  CHAI NAT      ชน
# 9     9            19          สระบุรี                  SARABURI      สบ
# 10   10            20           ชลบุรี                 CHON BURI      ชบ
# 11   11            21            ระยอง                    RAYONG      รย
# 12   12            22         จันทบุรี               CHANTHABURI      จบ
# 13   13            23             ตราด                      TRAT      ตร
# 14   14            24       ฉะเชิงเทรา              CHACHOENGSAO      ฉช
# 15   15            25       ปราจีนบุรี              PRACHIN BURI      ปจ
# 16   16            26          นครนายก              NAKHON NAYOK      นย
# 17   17            27          สระแก้ว                   SA KAEO      สก
# 18   18            30       นครราชสีมา         NAKHON RATCHASIMA      นม
# 19   19            31        บุรีรัมย์                  BURI RAM      บร
# 20   20            32         สุรินทร์                     SURIN      สร
# 21   21            33         ศรีสะเกษ                 SI SA KET      ศก
# 22   22            34      อุบลราชธานี          UBON RATCHATHANI      อบ
# 23   23            35            ยโสธร                  YASOTHON      ยส
# 24   24            36          ชัยภูมิ                CHAIYAPHUM      ชย
# 25   25            37       อำนาจเจริญ             AMNAT CHAROEN      อจ
# 26   26            38           บึงกาฬ                 BUENG KAN      บก
# 27   27            39      หนองบัวลำภู           NONG BUA LAMPHU      นภ
# 28   28            40          ขอนแก่น                 KHON KAEN      ขก
# 29   29            41         อุดรธานี                UDON THANI      อด
# ..  ...           ...              ...                       ...     ...
# 47   47            60        นครสวรรค์              NAKHON SAWAN      นว
# 48   48            61        อุทัยธานี               UTHAI THANI      อน
# 49   49            62        กำแพงเพชร            KAMPHAENG PHET      กพ
# 50   50            63              ตาก                       TAK      ตก
# 51   51            64          สุโขทัย                 SUKHOTHAI      สท
# 52   52            65         พิษณุโลก               PHITSANULOK      พล
# 53   53            66           พิจิตร                   PHICHIT      พจ
# 54   54            67        เพชรบูรณ์                PHETCHABUN      พช
# 55   55            70          ราชบุรี                RATCHABURI      รบ
# 56   56            71        กาญจนบุรี              KANCHANABURI      กจ
# 57   57            72       สุพรรณบุรี               SUPHAN BURI      สพ
# 58   58            73           นครปฐม             NAKHON PATHOM      นฐ
# 59   59            74        สมุทรสาคร              SAMUT SAKHON      สค
# 60   60            75      สมุทรสงคราม           SAMUT SONGKHRAM      สส
# 61   61            76         เพชรบุรี               PHETCHABURI      พบ
# 62   62            77  ประจวบคีรีขันธ์       PRACHUAP KHIRI KHAN      ปข
# 63   63            80    นครศรีธรรมราช       NAKHON SI THAMMARAT      นศ
# 64   64            81           กระบี่                     KRABI      กบ
# 65   65            82            พังงา                  PHANGNGA      พง
# 66   66            83           ภูเก็ต                    PHUKET      ภก
# 67   67            84     สุราษฎร์ธานี               SURAT THANI      สฎ
# 68   68            85            ระนอง                    RANONG      รน
# 69   69            86            ชุมพร                  CHUMPHON      ชพ
# 70   70            90            สงขลา                  SONGKHLA      สข
# 71   71            91             สตูล                     SATUN      สต
# 72   72            92             ตรัง                     TRANG      ตง
# 73   73            93           พัทลุง               PHATTHALUNG      พท
# 74   74            94          ปัตตานี                   PATTANI      ปน
# 75   75            95             ยะลา                      YALA      ยล
# 76   76            96         นราธิวาส                NARATHIWAT      นธ
#
#    abbr_e        region  FIPS       lat     lon      ...           gpp_2008  \
# 0     BKK       central  TH40  6.755200  1.5231      ...       2.928923e+06
# 1     SPK       central  TH42  6.849400  1.5036      ...       5.911303e+05
# 2     NBI       central  TH38  6.505300  1.5397      ...       1.527889e+05
# 3     PTE       central  TH39  6.815900  1.5555      ...       2.808179e+05
# 4     AYA       central  TH36  6.647400  1.5864      ...       3.711006e+05
# 5     ATG       central  TH35  6.453000  1.6170      ...       2.069173e+04
# 6     LRI       central  TH34  7.041400  1.6696      ...       6.125439e+04
# 7     SBR       central  TH33  6.447700  1.6491      ...       2.245641e+04
# 8     CNT       central  TH32  6.101200  1.6732      ...       2.700392e+04
# 9     SRI       central  TH37  7.171100  1.6180      ...       1.547551e+05
# 10    CBI       eastern  TH46  7.384900  1.4593      ...       6.150546e+05
# 11    RYG       eastern  TH47  7.633400  1.4223      ...       6.391149e+05
# 12    CTI       eastern  TH48  8.396100  1.4256      ...       6.986566e+04
# 13    TRT       eastern  TH49  8.831000  1.3639      ...       3.015604e+04
# 14    CCO       eastern  TH44  7.628500  1.5056      ...       2.253908e+05
# 15    PRI       eastern  TH74  7.859800  1.5550      ...       1.911561e+05
# 16    NYK       central  TH43  7.342700  1.5728      ...       1.623376e+04
# 17    SKW       eastern  TH80  8.590900  1.5265      ...       2.498254e+04
# 18    NMA  northeastern  TH27  8.342900  1.6560      ...       1.557811e+05
# 19    BRM  northeastern  TH28  9.259499  1.6422      ...       4.740511e+04
# 20    SRN  northeastern  TH29  1.001300  1.6509      ...       3.933032e+04
# 21    SSK  northeastern  TH30  1.078300  1.6495      ...       3.843217e+04
# 22    UBN  northeastern  TH75  1.157500  1.6878      ...       6.015364e+04
# 23    YST  northeastern  TH72  1.072200  1.7648      ...       1.558032e+04
# 24    CPM  northeastern  TH26  8.015200  1.7744      ...       3.414227e+04
# 25    ACR  northeastern  TH77  1.115300  1.7654      ...       9.379955e+03
# 26    BKN  northeastern  TH81  9.985400  2.0130      ...       0.000000e+00
# 27    NBP  northeastern  TH79  8.512700  1.9026      ...       1.387544e+04
# 28    KKN  northeastern  TH22  8.823000  1.8174      ...       1.268120e+05
# 29    UDN  northeastern  TH76  9.108600  1.9307      ...       6.160814e+04
# ..    ...           ...   ...       ...     ...      ...                ...
        self.FID = int(FID)
        self.ISO_province = int(ISO_province)
        self.PROV_NAMT = str(PROV_NAMT)
        self.PROV_NAME = str(PROV_NAME)
        self.data = kwargs
    
    def __hash__(self):
        return hash(self.__repr__())
    def __eq__(self, o):
        return self.__repr__() == o.__repr__()
    def __str__(self):
        return self.__repr__()
    def __repr__(self):
        return f'{self.__class__.__name__}> {self.PROV_NAME}: ({self.FID}, {self.ISO_province}, {self.PROV_NAME}, {self.PROV_NAMT})'

    @staticmethod
    def _invalid_instance():
        return Province(FID=-1, ISO_province=-1, PROV_NAMT="----", PROV_NAME="**INVALID**")


l = dict([(kwargs['PROV_NAME'], Province(**kwargs)) for kwargs in df.to_dict(orient='records')])
    
# l = [(Province(row.ISO_province, row.PROV_NAME, row)) for index, row in df.iterrows() ]
# for p in l:
#     print(p.as_txt())
l
# Out:
# {'BANGKOK': Province> BANGKOK: (0, 10, BANGKOK, กรุงเทพมหานคร),
#  'SAMUT PRAKAN': Province> SAMUT PRAKAN: (1, 11, SAMUT PRAKAN, สมุทรปราการ),
#  'NONTHABURI': Province> NONTHABURI: (2, 12, NONTHABURI, นนทบุรี),
#  'PATHUM THANI': Province> PATHUM THANI: (3, 13, PATHUM THANI, ปทุมธานี),
#  'PHRA NAKHON SI AYUTTHAYA': Province> PHRA NAKHON SI AYUTTHAYA: (4, 14, PHRA NAKHON SI AYUTTHAYA, พระนครศรีอยุธยา),
#  'ANG THONG': Province> ANG THONG: (5, 15, ANG THONG, อ่างทอง),
#  'LOP BURI': Province> LOP BURI: (6, 16, LOP BURI, ลพบุรี),
#  'SING BURI': Province> SING BURI: (7, 17, SING BURI, สิงห์บุรี),
#  'CHAI NAT': Province> CHAI NAT: (8, 18, CHAI NAT, ชัยนาท),
#  'SARABURI': Province> SARABURI: (9, 19, SARABURI, สระบุรี),
#  'CHON BURI': Province> CHON BURI: (10, 20, CHON BURI, ชลบุรี),
#  'RAYONG': Province> RAYONG: (11, 21, RAYONG, ระยอง),
#  'CHANTHABURI': Province> CHANTHABURI: (12, 22, CHANTHABURI, จันทบุรี),
#  'TRAT': Province> TRAT: (13, 23, TRAT, ตราด),
#  'CHACHOENGSAO': Province> CHACHOENGSAO: (14, 24, CHACHOENGSAO, ฉะเชิงเทรา),
#  'PRACHIN BURI': Province> PRACHIN BURI: (15, 25, PRACHIN BURI, ปราจีนบุรี),
#  'NAKHON NAYOK': Province> NAKHON NAYOK: (16, 26, NAKHON NAYOK, นครนายก),
#  'SA KAEO': Province> SA KAEO: (17, 27, SA KAEO, สระแก้ว),
#  'NAKHON RATCHASIMA': Province> NAKHON RATCHASIMA: (18, 30, NAKHON RATCHASIMA, นครราชสีมา),
#  'BURI RAM': Province> BURI RAM: (19, 31, BURI RAM, บุรีรัมย์),
#  'SURIN': Province> SURIN: (20, 32, SURIN, สุรินทร์),
#  'SI SA KET': Province> SI SA KET: (21, 33, SI SA KET, ศรีสะเกษ),
#  'UBON RATCHATHANI': Province> UBON RATCHATHANI: (22, 34, UBON RATCHATHANI, อุบลราชธานี),
#  'YASOTHON': Province> YASOTHON: (23, 35, YASOTHON, ยโสธร),
#  'CHAIYAPHUM': Province> CHAIYAPHUM: (24, 36, CHAIYAPHUM, ชัยภูมิ),
#  'AMNAT CHAROEN': Province> AMNAT CHAROEN: (25, 37, AMNAT CHAROEN, อำนาจเจริญ),
#  'BUENG KAN': Province> BUENG KAN: (26, 38, BUENG KAN, บึงกาฬ),
#  'NONG BUA LAMPHU': Province> NONG BUA LAMPHU: (27, 39, NONG BUA LAMPHU, หนองบัวลำภู),
#  'KHON KAEN': Province> KHON KAEN: (28, 40, KHON KAEN, ขอนแก่น),
#  'UDON THANI': Province> UDON THANI: (29, 41, UDON THANI, อุดรธานี),
#  'LOEI': Province> LOEI: (30, 42, LOEI, เลย),
#  'NONG KHAI': Province> NONG KHAI: (31, 43, NONG KHAI, หนองคาย),
#  'MAHA SARAKHAM': Province> MAHA SARAKHAM: (32, 44, MAHA SARAKHAM, มหาสารคาม),
#  'ROI ET': Province> ROI ET: (33, 45, ROI ET, ร้อยเอ็ด),
#  'KALASIN': Province> KALASIN: (34, 46, KALASIN, กาฬสินธุ์),
#  'SAKON NAKHON': Province> SAKON NAKHON: (35, 47, SAKON NAKHON, สกลนคร),
#  'NAKHON PHANOM': Province> NAKHON PHANOM: (36, 48, NAKHON PHANOM, นครพนม),
#  'MUKDAHAN': Province> MUKDAHAN: (37, 49, MUKDAHAN, มุกดาหาร),
#  'CHIANG MAI': Province> CHIANG MAI: (38, 50, CHIANG MAI, เชียงใหม่),
#  'LAMPHUN': Province> LAMPHUN: (39, 51, LAMPHUN, ลำพูน),
#  'LAMPANG': Province> LAMPANG: (40, 52, LAMPANG, ลำปาง),
#  'UTTARADIT': Province> UTTARADIT: (41, 53, UTTARADIT, อุตรดิตถ์),
#  'PHRAE': Province> PHRAE: (42, 54, PHRAE, แพร่),
#  'NAN': Province> NAN: (43, 55, NAN, น่าน),
#  'PHAYAO': Province> PHAYAO: (44, 56, PHAYAO, พะเยา),
#  'CHIANG RAI': Province> CHIANG RAI: (45, 57, CHIANG RAI, เชียงราย),
#  'MAE HONG SON': Province> MAE HONG SON: (46, 58, MAE HONG SON, แม่ฮ่องสอน),
#  'NAKHON SAWAN': Province> NAKHON SAWAN: (47, 60, NAKHON SAWAN, นครสวรรค์),
#  'UTHAI THANI': Province> UTHAI THANI: (48, 61, UTHAI THANI, อุทัยธานี),
#  'KAMPHAENG PHET': Province> KAMPHAENG PHET: (49, 62, KAMPHAENG PHET, กำแพงเพชร),
#  'TAK': Province> TAK: (50, 63, TAK, ตาก),
#  'SUKHOTHAI': Province> SUKHOTHAI: (51, 64, SUKHOTHAI, สุโขทัย),
#  'PHITSANULOK': Province> PHITSANULOK: (52, 65, PHITSANULOK, พิษณุโลก),
#  'PHICHIT': Province> PHICHIT: (53, 66, PHICHIT, พิจิตร),
#  'PHETCHABUN': Province> PHETCHABUN: (54, 67, PHETCHABUN, เพชรบูรณ์),
#  'RATCHABURI': Province> RATCHABURI: (55, 70, RATCHABURI, ราชบุรี),
#  'KANCHANABURI': Province> KANCHANABURI: (56, 71, KANCHANABURI, กาญจนบุรี),
#  'SUPHAN BURI': Province> SUPHAN BURI: (57, 72, SUPHAN BURI, สุพรรณบุรี),
#  'NAKHON PATHOM': Province> NAKHON PATHOM: (58, 73, NAKHON PATHOM, นครปฐม),
#  'SAMUT SAKHON': Province> SAMUT SAKHON: (59, 74, SAMUT SAKHON, สมุทรสาคร),
#  'SAMUT SONGKHRAM': Province> SAMUT SONGKHRAM: (60, 75, SAMUT SONGKHRAM, สมุทรสงคราม),
#  'PHETCHABURI': Province> PHETCHABURI: (61, 76, PHETCHABURI, เพชรบุรี),
#  'PRACHUAP KHIRI KHAN': Province> PRACHUAP KHIRI KHAN: (62, 77, PRACHUAP KHIRI KHAN, ประจวบคีรีขันธ์),
#  'NAKHON SI THAMMARAT': Province> NAKHON SI THAMMARAT: (63, 80, NAKHON SI THAMMARAT, นครศรีธรรมราช),
#  'KRABI': Province> KRABI: (64, 81, KRABI, กระบี่),
#  'PHANGNGA': Province> PHANGNGA: (65, 82, PHANGNGA, พังงา),
#  'PHUKET': Province> PHUKET: (66, 83, PHUKET, ภูเก็ต),
#  'SURAT THANI': Province> SURAT THANI: (67, 84, SURAT THANI, สุราษฎร์ธานี),
#  'RANONG': Province> RANONG: (68, 85, RANONG, ระนอง),
#  'CHUMPHON': Province> CHUMPHON: (69, 86, CHUMPHON, ชุมพร),
#  'SONGKHLA': Province> SONGKHLA: (70, 90, SONGKHLA, สงขลา),
#  'SATUN': Province> SATUN: (71, 91, SATUN, สตูล),
#  'TRANG': Province> TRANG: (72, 92, TRANG, ตรัง),
#  'PHATTHALUNG': Province> PHATTHALUNG: (73, 93, PHATTHALUNG, พัทลุง),
#  'PATTANI': Province> PATTANI: (74, 94, PATTANI, ปัตตานี),
#  'YALA': Province> YALA: (75, 95, YALA, ยะลา),
#  'NARATHIWAT': Province> NARATHIWAT: (76, 96, NARATHIWAT, นราธิวาส)}

# %%
class ProvinceRelationParser:
    def __init__(self, relations_input_dataset:str=None, province_lookup:dict=None, ignore_parse_lines:list=[""]):
        self._province_lookup = province_lookup
        self.province_relations = {}
        self._province_naming_errors=[]
        self._relation_error = []
        
        self.__parse( relations_input_dataset, ignore_parse_lines )
        self.__has_valid_mutual_borders()

    def __parse(self, relations_input_dataset, ignore_parse_lines=[""]):
        # remove blank lines
        relations_input_dataset = [l for l in relations_input_dataset if l not in ignore_parse_lines]
        for s in relations_input_dataset:
            prov, neighbours = self._get_relation_from_text(s)
            self.province_relations[prov] = neighbours
        
    def _get_relation_from_text(self, s):
        arr = s.split("->")
        k = arr[0].strip().upper()
        k = self.__is_valid_name_lookup_or_else( k , source=k )
        v = [ self.__is_valid_name_lookup_or_else( v.strip().upper() , source=k ) for v in arr[1].split(",") ]
        return k , v

    def __is_valid_name_lookup_or_else(self, k, source):
        if k in self._province_lookup:
            ret = self._province_lookup[ k ]
        else:
            self._province_naming_errors+=[f"Missing Province Lookup: {source} -> {k}"]
            ret = Province._invalid_instance()
        return ret
    
    def __has_valid_mutual_borders(self):
        """
        True: curr_province has pv in curr_province's neighbour_provinces.
        Test: confirm curr_province is in pv's neighbour_provinces.
        """
        c=0
        for curr_province , neighbour_provinces in self.province_relations.items():
            c+=1
            # True: pv is in curr_province's neighbour_provinces.
            for pv in neighbour_provinces:
                # Test: Neighbour exists:
                if pv not in self.province_relations:
                    self._relation_error += [f"{c}. Missing Province Neighbour Entry for {curr_province.PROV_NAME} -> {pv.PROV_NAME}."]
                    continue
                pv_neighbours = self.province_relations[pv] # lookup to find another province's neighbours          
                # Test: curr_province is in pv's neighbour_provinces.
                if curr_province not in pv_neighbours: 
                    self._relation_error += [f"{c}. Missing Mutual Neighbour for {curr_province.PROV_NAME} -> {pv.PROV_NAME}."]
                    continue
                    
    def _report_relation_errors(self):        
        return "Province Relation Errors:\n"+("\n".join(self._relation_error)) if len(self._relation_error) > 0 else "Province Relation Errors: None Found"
    
    def _report_province_naming_errors(self):
        return "Province Name Errors:\n"+("\n".join(self._province_naming_errors)) if len(self._province_naming_errors) > 0 else "Province Name Errors: None Found"

    def __repr__(self):
        
        
        r = [self._report_relation_errors(), self._report_province_naming_errors(),"","Province Neighbour Relations:"]
        for p,neighbour in self.province_relations.items():
            r.append( f"{p.PROV_NAME}:\n" + "\n".join(["\t"+n.PROV_NAME for n in neighbour]) )
        return "\n".join(r)

    
def test_invalid_province_name_list():
    s = "Nong Khai -> Bueng Kan, Udon Thani, Sakon Nakhon, Loei"
    s1 = "Bueng Kan -> Nakhon Phanom, Sakon Nakhon, Nong Khai, sss"
    return [s,"",s1]

def test_list_mutual_positions():
    l = ["Nong Khai -> Bueng Kan", 
         "Bueng Kan -> Nong Khai"
        ]
    return l


def test_list_invalid_mutual_positions():
    l = ["Nong Khai -> Bueng Kan", 
         "Bueng Kan -> Nong Khai, Nakhon Phanom",
         "Nakhon Phanom -> Bueng Kan, Nong Khai" # Mutual relation missing for Bueng Kan.
        ]
    return l

def read_relations_dataset(filename):
    lines = []
    with open(filename, 'r') as fd:
        lines = fd.read().split("\n")
    lines = [l for l in lines if l != ""]
    return lines

text_list = read_relations_dataset('thailand_province_relations.txt')
# text_list = test_invalid_province_name_list()
# text_list = test_list_invalid_mutual_positions()

prp = ProvinceRelationParser(text_list,l)
print( prp )
# Out:
# Province Relation Errors: None Found
# Province Name Errors: None Found
#
# Province Neighbour Relations:
# NONG KHAI:
# 	BUENG KAN
# 	UDON THANI
# 	SAKON NAKHON
# 	LOEI
# BUENG KAN:
# 	NAKHON PHANOM
# 	SAKON NAKHON
# 	NONG KHAI
# NAKHON PHANOM:
# 	SAKON NAKHON
# 	MUKDAHAN
# 	BUENG KAN
# MUKDAHAN:
# 	NAKHON PHANOM
# 	SAKON NAKHON
# 	KALASIN
# 	ROI ET
# 	YASOTHON
# 	AMNAT CHAROEN
# SAKON NAKHON:
# 	NAKHON PHANOM
# 	BUENG KAN
# 	NONG KHAI
# 	UDON THANI
# 	KALASIN
# 	MUKDAHAN
# KALASIN:
# 	SAKON NAKHON
# 	MUKDAHAN
# 	ROI ET
# 	MAHA SARAKHAM
# 	KHON KAEN
# 	UDON THANI
# KHON KAEN:
# 	UDON THANI
# 	KALASIN
# 	MAHA SARAKHAM
# 	BURI RAM
# 	NAKHON RATCHASIMA
# 	CHAIYAPHUM
# 	PHETCHABUN
# 	LOEI
# 	NONG BUA LAMPHU
# MAHA SARAKHAM:
# 	KALASIN
# 	ROI ET
# 	SURIN
# 	BURI RAM
# 	KHON KAEN
# ROI ET:
# 	KALASIN
# 	MUKDAHAN
# 	YASOTHON
# 	SI SA KET
# 	SURIN
# 	MAHA SARAKHAM
# YASOTHON:
# 	MUKDAHAN
# 	AMNAT CHAROEN
# 	UBON RATCHATHANI
# 	SI SA KET
# 	ROI ET
# AMNAT CHAROEN:
# 	MUKDAHAN
# 	UBON RATCHATHANI
# 	YASOTHON
# UBON RATCHATHANI:
# 	AMNAT CHAROEN
# 	YASOTHON
# 	SI SA KET
# SI SA KET:
# 	UBON RATCHATHANI
# 	YASOTHON
# 	ROI ET
# 	SURIN
# SURIN:
# 	SI SA KET
# 	ROI ET
# 	MAHA SARAKHAM
# 	BURI RAM
# BURI RAM:
# 	SURIN
# 	MAHA SARAKHAM
# 	KHON KAEN
# 	NAKHON RATCHASIMA
# 	SA KAEO
# NAKHON RATCHASIMA:
# 	KHON KAEN
# 	BURI RAM
# 	CHAIYAPHUM
# 	LOP BURI
# 	SARABURI
# 	NAKHON NAYOK
# 	PRACHIN BURI
# 	SA KAEO
# UDON THANI:
# 	NONG KHAI
# 	SAKON NAKHON
# 	KALASIN
# 	KHON KAEN
# 	NONG BUA LAMPHU
# 	LOEI
# NONG BUA LAMPHU:
# 	UDON THANI
# 	LOEI
# 	KHON KAEN
# LOEI:
# 	NONG KHAI
# 	UDON THANI
# 	NONG BUA LAMPHU
# 	KHON KAEN
# 	PHETCHABUN
# 	PHITSANULOK
# CHAIYAPHUM:
# 	KHON KAEN
# 	NAKHON RATCHASIMA
# 	LOP BURI
# 	PHETCHABUN
# PHETCHABUN:
# 	LOEI
# 	KHON KAEN
# 	CHAIYAPHUM
# 	LOP BURI
# 	NAKHON SAWAN
# 	PHICHIT
# 	PHITSANULOK
# PHITSANULOK:
# 	LOEI
# 	PHETCHABUN
# 	PHICHIT
# 	KAMPHAENG PHET
# 	SUKHOTHAI
# 	UTTARADIT
# UTTARADIT:
# 	PHITSANULOK
# 	SUKHOTHAI
# 	PHRAE
# 	NAN
# NAN:
# 	PHAYAO
# 	PHRAE
# 	UTTARADIT
# PHAYAO:
# 	NAN
# 	PHRAE
# 	LAMPANG
# 	CHIANG RAI
# CHIANG RAI:
# 	CHIANG MAI
# 	LAMPANG
# 	PHAYAO
# PHRAE:
# 	NAN
# 	UTTARADIT
# 	SUKHOTHAI
# 	LAMPANG
# 	PHAYAO
# SUKHOTHAI:
# 	PHRAE
# 	UTTARADIT
# 	LAMPANG
# 	TAK
# 	KAMPHAENG PHET
# 	PHITSANULOK
# LAMPANG:
# 	CHIANG RAI
# 	PHAYAO
# 	PHRAE
# 	SUKHOTHAI
# 	TAK
# 	LAMPHUN
# 	CHIANG MAI
# CHIANG MAI:
# 	CHIANG RAI
# 	LAMPANG
# 	LAMPHUN
# 	TAK
# 	MAE HONG SON
# LAMPHUN:
# 	LAMPANG
# 	CHIANG MAI
# 	TAK
# MAE HONG SON:
# 	CHIANG MAI
# 	TAK
# KAMPHAENG PHET:
# 	TAK
# 	SUKHOTHAI
# 	PHITSANULOK
# 	PHICHIT
# 	NAKHON SAWAN
# PHICHIT:
# 	PHITSANULOK
# 	PHETCHABUN
# 	KAMPHAENG PHET
# 	NAKHON SAWAN
# NAKHON SAWAN:
# 	KAMPHAENG PHET
# 	PHICHIT
# 	PHETCHABUN
# 	LOP BURI
# 	SING BURI
# 	CHAI NAT
# 	UTHAI THANI
# 	TAK
# TAK:
# 	KANCHANABURI
# 	UTHAI THANI
# 	NAKHON SAWAN
# 	KAMPHAENG PHET
# 	SUKHOTHAI
# 	LAMPANG
# 	LAMPHUN
# 	CHIANG MAI
# 	MAE HONG SON
# UTHAI THANI:
# 	SUPHAN BURI
# 	CHAI NAT
# 	NAKHON SAWAN
# 	TAK
# 	KANCHANABURI
# CHAI NAT:
# 	SING BURI
# 	NAKHON SAWAN
# 	UTHAI THANI
# 	SUPHAN BURI
# SING BURI:
# 	ANG THONG
# 	LOP BURI
# 	NAKHON SAWAN
# 	CHAI NAT
# 	SUPHAN BURI
# LOP BURI:
# 	SARABURI
# 	NAKHON RATCHASIMA
# 	CHAIYAPHUM
# 	PHETCHABUN
# 	NAKHON SAWAN
# 	SING BURI
# 	ANG THONG
# 	PHRA NAKHON SI AYUTTHAYA
# SUPHAN BURI:
# 	KANCHANABURI
# 	NAKHON PATHOM
# 	PHRA NAKHON SI AYUTTHAYA
# 	ANG THONG
# 	SING BURI
# 	CHAI NAT
# 	UTHAI THANI
# ANG THONG:
# 	SUPHAN BURI
# 	PHRA NAKHON SI AYUTTHAYA
# 	LOP BURI
# 	SING BURI
# KANCHANABURI:
# 	RATCHABURI
# 	NAKHON PATHOM
# 	SUPHAN BURI
# 	UTHAI THANI
# 	TAK
# PHRA NAKHON SI AYUTTHAYA:
# 	PATHUM THANI
# 	SARABURI
# 	LOP BURI
# 	ANG THONG
# 	SUPHAN BURI
# 	NAKHON PATHOM
# 	NONTHABURI
# SARABURI:
# 	NAKHON NAYOK
# 	NAKHON RATCHASIMA
# 	LOP BURI
# 	PHRA NAKHON SI AYUTTHAYA
# 	PATHUM THANI
# NAKHON NAYOK:
# 	CHACHOENGSAO
# 	PRACHIN BURI
# 	NAKHON RATCHASIMA
# 	SARABURI
# 	PATHUM THANI
# PATHUM THANI:
# 	BANGKOK
# 	NONTHABURI
# 	PHRA NAKHON SI AYUTTHAYA
# 	SARABURI
# 	NAKHON NAYOK
# 	CHACHOENGSAO
# NONTHABURI:
# 	BANGKOK
# 	NAKHON PATHOM
# 	PHRA NAKHON SI AYUTTHAYA
# 	PATHUM THANI
# NAKHON PATHOM:
# 	SAMUT SAKHON
# 	BANGKOK
# 	NONTHABURI
# 	PHRA NAKHON SI AYUTTHAYA
# 	SUPHAN BURI
# 	KANCHANABURI
# 	RATCHABURI
# BANGKOK:
# 	SAMUT SAKHON
# 	NAKHON PATHOM
# 	NONTHABURI
# 	PATHUM THANI
# 	CHACHOENGSAO
# 	SAMUT PRAKAN
# SAMUT SAKHON:
# 	SAMUT SONGKHRAM
# 	RATCHABURI
# 	BANGKOK
# 	NAKHON PATHOM
# SAMUT PRAKAN:
# 	CHACHOENGSAO
# 	BANGKOK
# PRACHIN BURI:
# 	CHACHOENGSAO
# 	SA KAEO
# 	NAKHON RATCHASIMA
# 	NAKHON NAYOK
# SA KAEO:
# 	CHANTHABURI
# 	CHACHOENGSAO
# 	PRACHIN BURI
# 	NAKHON RATCHASIMA
# 	BURI RAM
# CHACHOENGSAO:
# 	CHON BURI
# 	CHANTHABURI
# 	SA KAEO
# 	PRACHIN BURI
# 	NAKHON NAYOK
# 	PATHUM THANI
# 	BANGKOK
# 	SAMUT PRAKAN
# CHON BURI:
# 	RAYONG
# 	CHANTHABURI
# 	CHACHOENGSAO
# RAYONG:
# 	CHON BURI
# 	CHANTHABURI
# CHANTHABURI:
# 	TRAT
# 	RAYONG
# 	SA KAEO
# 	CHON BURI
# 	CHACHOENGSAO
# TRAT:
# 	CHANTHABURI
# SAMUT SONGKHRAM:
# 	RATCHABURI
# 	PHETCHABURI
# 	SAMUT SAKHON
# RATCHABURI:
# 	PHETCHABURI
# 	SAMUT SONGKHRAM
# 	SAMUT SAKHON
# 	NAKHON PATHOM
# 	KANCHANABURI
# PHETCHABURI:
# 	PRACHUAP KHIRI KHAN
# 	RATCHABURI
# 	SAMUT SONGKHRAM
# PRACHUAP KHIRI KHAN:
# 	CHUMPHON
# 	PHETCHABURI
# CHUMPHON:
# 	RANONG
# 	SURAT THANI
# 	PRACHUAP KHIRI KHAN
# RANONG:
# 	PHANGNGA
# 	SURAT THANI
# 	CHUMPHON
# PHANGNGA:
# 	PHUKET
# 	KRABI
# 	SURAT THANI
# 	RANONG
# SURAT THANI:
# 	PHANGNGA
# 	KRABI
# 	NAKHON SI THAMMARAT
# 	CHUMPHON
# 	RANONG
# PHUKET:
# 	PHANGNGA
# KRABI:
# 	NAKHON SI THAMMARAT
# 	TRANG
# 	SURAT THANI
# 	PHANGNGA
# NAKHON SI THAMMARAT:
# 	PHATTHALUNG
# 	KRABI
# 	SONGKHLA
# 	SURAT THANI
# 	TRANG
# TRANG:
# 	SATUN
# 	PHATTHALUNG
# 	NAKHON SI THAMMARAT
# 	KRABI
# PHATTHALUNG:
# 	SONGKHLA
# 	SATUN
# 	TRANG
# 	NAKHON SI THAMMARAT
# SATUN:
# 	SONGKHLA
# 	TRANG
# 	PHATTHALUNG
# SONGKHLA:
# 	PATTANI
# 	YALA
# 	SATUN
# 	PHATTHALUNG
# 	NAKHON SI THAMMARAT
# PATTANI:
# 	NARATHIWAT
# 	YALA
# 	SONGKHLA
# YALA:
# 	NARATHIWAT
# 	PATTANI
# 	SONGKHLA
# NARATHIWAT:
# 	YALA
# 	PATTANI
